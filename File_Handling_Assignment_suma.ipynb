# %%
# Write a function in python to read the content from 
# a text file "poem.txt" line by line and display the same on screen.
f=open("poem.txt","r")
content=f.read()
print(content)
f.close()

# %%
# Write a function in python to count the number of lines 
# from a text file "story.txt" which is not starting with an alphabet "T". 

# Example: If the file "story.txt" contains the following lines: A boy is playing there.
# There is a playground.
# An aeroplane is in the sky.
# The sky is pink.
# Alphabets and numbers are allowed in the password.
# The function should display the output as 3
f=open("story.txt","r")
content=f.readlines()
cnt=0
for each in content:s
     if each[0]!='T':
        cnt+=1
print(cnt)
f.close()

# %%
# Write a function in Python to count and display the total number of words in a text file.
f=open('my_mod.txt','r')
content=f.read()
f.close
totWords=0
for char in content:
    if(char==" "):
        totWords+=1    
print("number of words in file are :",totWords)

# %%
# Write a function in Python to read lines from a text file "notes.txt". 
# Your function should find and display the occurrence of the word "the".

# For example: If the content of the file is:
# "India is the fastest-growing economy. India is looking for more investments around the globe. The whole world is looking at India as a great market. Most of the Indians can foresee the heights that India is capable of reaching."

# The output should be 5.
f=open('notes.txt','r')
content=f.read()
f.close
cnt=0
data=content.split()
for word in data:
#     print(word)
    if(word=='The' or word=='the'):
        cnt+=1
print(cnt)

# %%
# Write a function display_words() in python to read lines from a text file "story.txt", 
# and display those words, which are less than 4 characters.
f=open('story.txt','r')
content=f.read()
f.close
cnt=0
data=content.split()
for word in data:
#     print(word)
    if(len(word)<4):
        cnt+=1
print(cnt)

# %%
# Write a function in Python to count the words "this" and "these" present in a text file "article.txt". 
# [Note that the words "this" and "these" are complete words] 
f=open('article.txt','r')
content=f.read()
f.close
cnt=0
data=content.split()
print(data)
for word in data:
#     print(word)
    if(word=='This' or word=='this' or word=='These' or word=='these'):
        cnt+=1
print(cnt)

# %%
# Write a function in Python to count words in a text file those are ending with alphabet "e"
f=open('article.txt','r')
content=f.read()
f.close
cnt=0
data=content.split()
print(list(filter(lambda x:x[len(x)-1]=="r",data)))
# print(func(data))

# %%
# Write a function in Python to count uppercase character in a text file.
import functools
with open('article.txt', 'r') as f:
    content=f.read()
    cnt=0
    print(list(filter(lambda x:x.isupper(),content)))
    print(functools.reduce(lambda x,y:x+y ,map(lambda x: 1,list(filter(lambda x:x.isupper(),content)))))
# print(len(list(filter(lambda x:x.isupper(),content)))) This code works with this print also

# %%
# A text file named "matter.txt" contains some text, which needs to be displayed such that 
# every next character is separated by a symbol "#". 
# Write a function definition for hash_display() in Python that would display 
# the entire content of the file matter.txt in the desired format.

# Example :
# If the file matter.txt has the following content stored in it :
# THE WORLD IS ROUND

# The function hash_display() should display the following content :
# T#H#E# #W#O#R#L#D# #I#S# #R#O#U#N#D#
with open('article.txt', 'r') as f:
    content=f.read()
    for i in content:
        print(i,end="#")

# %%
# Aditi has used a text editing software to type some text. After saving the article as WORDS.TXT, 
# she realised that she has wrongly typed alphabet J in place of alphabet I everywhere in the article.
# Write a function definition for JTOI() in Python that would display the corrected version of entire content 
# of the file WORDS.TXT with all the alphabets "J" to be displayed as an alphabet "I" on screen.

# Note: Assuming that WORD.TXT does not contain any J alphabet otherwise.

# Example:
# If Aditi has stored the following content in the file WORDS.TXT:
# WELL, THJS JS A WORD BY JTSELF. YOU COULD STRETCH THJS TO BE A SENTENCE
# The function JTOI() should display the following content:
# WELL, THIS IS A WORD BY ITSELF. YOU COULD STRETCH THIS TO BE A SENTENCE
with open('words.txt', 'r') as f:
    content=f.read()
    print(content.replace("J","I"))

# %%
# Write a function AMCount() in Python, which should read each character of a text file STORY.TXT, 
# should count and display the occurance of alphabets A and M (including small cases a and m too).
# For Example:
# If the file content is as follows:
# Updated information
# As simplified by official websites.
# The EUCount() function should display the output as:
# A or a:4
# M or m :2
def AMCount():    
    with open('words.txt', 'r') as f:
        content=f.read()
        cntA=0
        cntM=0
        for ch in content:
            if(ch=="A" or ch == "a"):
                cntA+=1
            if(ch=="M" or ch == "m"):
                cntM+=1
    return cntA,cntM
a,b= AMCount()
print("A or a:",a)
print("M or m:",b)

# %%
# A binary file "Book.dat" has structure [BookNo, Book_Name, Author, Price].
# i. Write a user defined function createFile() to input data for a record and add to Book.dat.
# ii. Write a function countRec(Author) in Python which accepts the Author name as parameter 
# and count and return number of books by the given Author are stored in the binary file "Book.dat"
import pickle
def CreateFile(f):    
    recNos=int(input("Enter the number of required records"))
    for i in range(recNos):
        BookNo=int(input('Enter the Book Number: '))
#     pickle.dump(str(BookNo),f)
        Book_Name=input('Enter the Book Name: ')
#     pickle.dump(Book_Name,f)
        Author=input('Enter the name of Author: ')
#     pickle.dump(Author,f)
        Price=eval(input('Enter the price of the book: '))
#     pickle.dump(str(Price),f)
        pickle.dump([BookNo,Book_Name,Author,Price],f)

def CountRec(Author): 
    fobj=open("Book.dat","rb")  
    num = 0 
    try: 
        while True: 
            rec=pickle.load(fobj)  
#             print(rec)
            if Author==rec[2]: 
                num = num + 1  
    except: 
        fobj.close()  
        return num

f=open('book.dat','wb+')
CreateFile(f)
f.close()
f=open('book.dat','rb')
# f.seek(0)
try:
    while True: 
            content = pickle.load(f)
            print(content)
except: 
        f.close() 
CountRec("au1")

# %%
# A binary file "STUDENT.DAT" has structure (admission_number, Name, Percentage). 
# Write a function count_rec() in Python that would read contents of the file "STUDENT.DAT" 
# and display the details of those students whose percentage is above 75. 
# Also display number of students scoring above 75%
import pickle
def CreateFile(f):    
    recNos=int(input("Enter the number of required records"))
    for i in range(recNos):
        admNo=int(input('Enter the admission_number: '))
        std_Name=input('Enter the Name: ')
        percentage=eval(input('Enter the percentage: '))
        pickle.dump([admNo,std_Name,percentage],f)
def CountRec(): 
    fobj=open("STUDENT.dat","rb")  
    lst=[]
    try: 
        while True: 
            rec=pickle.load(fobj)  
#             print("here",rec[1])
            if rec[2]>75: 
#                 print("here1",rec)
                lst.append(rec)
    except: 
#         print("coming to exception")
        fobj.close()  
        return lst
f=open('STUDENT.dat','wb+')
CreateFile(f)
f.close()
# f=open('STUDENT.dat','rb')
# content=pickle.load(f)
# print("content",content)
print("here3",CountRec())

# %%
###### Given a binary file employee.dat, created using dictionary object having keys: (empcode, name, and salary)

# Write a python function that add one more record at the end of file.
# Write a python function that display all employee records whose salary is more that 30000
import pickle
def addRecord(f):    
        empCode=int(input('Enter the employee_number: '))
        empName=input('Enter the Name: ')
        salary=eval(input('Enter the Salary: '))
        pickle.dump([empCode,empName,salary],f)
def fatSal(): 
    fobj=open("employee.dat","rb")  
    lst=[]
    try: 
        while True: 
            rec=pickle.load(fobj)  
#             print("here",rec[1])
            if rec[2]>30000: 
#                 print("here1",rec)
                lst.append(rec)
    except: 
#         print("coming to exception")
        fobj.close()  
        return lst
f=open("employee.dat","ab+")
addRecord(f)
f.close()
print(fatSal())

# %%
# Write a function to search and display details of student whose rollno is '1005' 
# from the binary file student.dat having structure [rollno, name, class and fees].
import pickle
def addRecord(f):    
        stdCode=int(input('Enter the role_number: '))
        stdName=input('Enter the Name: ')
        stdClass=int(input('Enter the Class: '))
        salary=eval(input('Enter the fee: '))
        pickle.dump([stdCode,stdName,stdClass,salary],f)
def searchStd(stdRollNo): 
    fobj=open("std.dat","rb")  
    lst=[]
    try: 
        while True: 
            rec=pickle.load(fobj)  
            if rec[0]==stdRollNo: 
                lst.append(rec)
    except: 
#         print("coming to exception")
        fobj.close()  
        return lst
f=open("std.dat","ab+")
addRecord(f)
f.close()
print(searchStd(1005))

# %%
# A binary file school.dat has structure(rollno, name, class, fees)

# Write a definition for function total_fees( ) that reads each object of file and calculate 
# the total fees of students and display the same.
f=open("std.dat","rb+")
sum=0
try:
    while True:
        rec=pickle.load(f) 
        sum+=rec[3]
except:
    f.close()
    print(sum)

# %%
# A binary file players.dat, containing records of following list format: [code, name, country and total runs]

# 1. Write a python function that display all records where player name starts from 'A'
# 2. Write a python function that accept country as an argument and count and display 
#     the number of players of that country.
# 3. Write a python function that add one record at the end of file.
import pickle
def addRecord(f):    
        playerCode=int(input('Enter the Player_number: '))
        playerName=input('Enter the Name: ')
        playerCountry=input('Enter the country: ')
        playerRuns=int(input('Enter the runs: '))
        pickle.dump([playerCode,playerName,playerCountry,playerRuns],f)
def countryPlayers(cntryName):
    fobj=open("player.dat","rb")  
    cnt=0
    try:
        while True: 
            rec=pickle.load(fobj)  
            if(rec[2]==cntryName):
                cnt+=1
    except:
        fobj.close()
        return cnt
    
def playerCount(alpha): 
    fobj=open("player.dat","rb")  
    cnt=0
    try: 
        while True: 
            rec=pickle.load(fobj)
            if rec[1][0]=="A":
                cnt+=1
    except: 
        fobj.close()  
        return cnt
f=open("player.dat","ab+")
addRecord(f)
f.close()
print(countryPlayers("Italy"))
print(playerCount("A"))

# %%
# Given a binary file game.dat, containing records of following list format: [game_name, participants]

# Write a function in Python that would read contents from the file game.dat and 
# creates a file named basket.dat copying only those records from game.dat where the game name is "Basket Ball"
import pickle
def addRecord(f):
    recNos=int(input("Enter the number of required records"))
    for i in range(recNos):
        game_name=input('Enter the game name: ')
        participants=input('Enter the Name: ')
        pickle.dump([game_name,participants],f)
def copyrecords(f,f1):
    try:
        while True:
            rec=pickle.load(f)
            if rec[0]=="BasketBall":
                pickle.dump(rec,f1)
    except:
        f.close()
        f1.close()
def readBasketRecord(f1):
    lst=[]
    try:
        while True:
            rec=pickle.load(f1)
            lst.append(rec)
    except:
        f1.close()
        return lst
                
f=open("game.dat","wb+")
addRecord(f)
f.close()
f=open("game.dat","rb")
f1=open("basket.dat","wb+")
copyrecords(f,f1)
f1=open("basket.dat","rb")
readBasketRecord(f1)
# Out:
# Enter the number of required records4
# Enter the game name: BasketBall
# Enter the Name: p1
# Enter the game name: BasketBall
# Enter the Name: p2
# Enter the game name: cricket
# Enter the Name: p3
# Enter the game name: cricket
# Enter the Name: p4
# [['BasketBall', 'p1'], ['BasketBall', 'p2']]
